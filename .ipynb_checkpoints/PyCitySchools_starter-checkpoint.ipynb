# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup    --------  PERSONAL WORK COPY GEORGE MCGUIRE  -------
import pandas as pd
import numpy as np
# File to Load (Remember to Change These)
school_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

# Read School and Student Data File and store into Pandas Data Frames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])

# %% [markdown]
# # District Summary
#
# * Calculate the total number of schools
#
# * Calculate the total number of students
#
# * Calculate the total budget
#
# * Calculate the average math score
#
# * Calculate the average reading score
#
# * Calculate the overall passing rate (overall average score), i.e. (avg. math score + avg. reading score)/2
#
# * Calculate the percentage of students with a passing math score (70 or greater)
#
# * Calculate the percentage of students with a passing reading score (70 or greater)
#
# * Create a dataframe to hold the above results
#
# * Optional: give the displayed data cleaner formatting

# %%
school_data_complete.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %%
# Create a high level snapshot (in table form) of the district's key metrics, including:
Class_df = school_data_complete.groupby(["school_name"]).sum()
Class_df = Class_df.reset_index()
Class_df["school_name"].count()
# answer is 15
# Out:
# 15

# %%
# Calculate the total number of students
number_of_students = school_data_complete["student_name"].count()
number_of_students
# answer is 39170
# Out:
# 39170

# %%
# Calculate the total budget
Budget_list = school_data_complete["budget"].drop_duplicates()
total_budget = Budget_list.sum()
total_budget
# Out:
# 24649428

# %%
# Calculate the average math score 
average_math_score = school_data_complete["math_score"].mean()
average_math_score
# Out:
# 78.98537145774827

# %%
# Calculate the average reading score
reading_score = school_data_complete["reading_score"].mean()
reading_score
# Out:
# 81.87784018381414

# %%
# Calculate the overall passing rate (overall average score), i.e. (avg. math score + avg. reading score)/2
passing_rate_average = (average_math_score + reading_score)/2
passing_rate_average
# Out:
# 80.43160582078121

# %%
# Calculate the percentage of students with a passing math score (70 or greater)
passing_math_score = school_data_complete["math_score"]>70
passed_math = (passing_math_score.value_counts()/number_of_students)*100
passed_math
# Out:
# True     72.392137
# False    27.607863
# Name: math_score, dtype: float64

# %% [markdown]
# ## School Summary

# %% [markdown]
# * Create an overview table that summarizes key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per Student Budget
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)
#
# * Create a dataframe to hold the above results

# %%
school_student_col = school_data_complete.groupby(["school_name", "type"]).count()["Student ID"]

per_school_budget = school_data_complete.groupby(["school_name", "type"]).mean()["budget"]

per_school_capita = per_school_budget / school_student_col

avg_math_score = school_data_complete.groupby(["school_name", "type"]).mean()["math_score"]

per_school_passing_math = passing_math_df.groupby(["school_name", "type"]).mean()["math_score"]

#avg_reading_score = 
avg_reading_score = school_data_complete.groupby(["school_name", "type"]).mean()["reading_score"]

# filter raw dataset to only contain passing records
passing_math_df = school_data_complete[school_data_complete["math_score"] > 70]
#passing_reading_df = 

#per_school_passing_reading =
per_school_passing_reading = passing_math_df.groupby(["school_name", "type"]).mean()["reading_score"]


overall_passing = (per_school_passing_math + per_school_passing_reading)/2

overall_passing
# Out:
# school_name            type
# Bailey High School     District    82.962687
# Cabrera High School    Charter     84.314603
# Figueroa High School   District    82.980851
# Ford High School       District    82.821766
# Griffin High School    Charter     84.388003
# Hernandez High School  District    83.113296
# Holden High School     Charter     84.608527
# Huang High School      District    82.947482
# Johnson High School    District    83.036349
# Pena High School       Charter     84.645125
# Rodriguez High School  District    82.705699
# Shelton High School    Charter     84.286797
# Thomas High School     Charter     84.442712
# Wilson High School     Charter     84.375723
# Wright High School     Charter     84.581846
# dtype: float64

# %%
per_school_summary = pd.DataFrame({
    "Total Students": school_student_col,
    "Total School Budget": per_school_budget,
    "Per Student Budget": per_school_capita,
    "Average Math Score": avg_math_score,
    "Average Reading Score": avg_reading_score,
    "Per school passing math": per_school_passing_math,
    "Per school passing reading": per_school_passing_reading,
    "Overall Passing": overall_passing
})
#    "Average Reading Score":,
avg_reading_score

#    "% Passing Math":,
per_school_passing_math
    
#    "% Passing Reading":,
per_school_passing_reading
    
#    "Overall Passing Rate":,
overall_passing

per_school_summary.head(5)
# Out:
#                                 Total Students  Total School Budget  \
# school_name           type
# Bailey High School    District            4976            3124928.0
# Cabrera High School   Charter             1858            1081356.0
# Figueroa High School  District            2949            1884411.0
# Ford High School      District            2739            1763916.0
# Griffin High School   Charter             1468             917500.0
# Hernandez High School District            4635            3022020.0
#
#                                 Per Student Budget  Average Math Score  \
# school_name           type
# Bailey High School    District               628.0           77.048432
# Cabrera High School   Charter                582.0           83.061895
# Figueroa High School  District               639.0           76.711767
# Ford High School      District               644.0           77.102592
# Griffin High School   Charter                625.0           83.351499
# ...

# %% [markdown]
# ## Top Performing Schools (By Passing Rate)

# %% [markdown]
# * Sort and display the top five schools in overall passing rate

# %%
top_performing_schools = per_school_summary.sort_values(["Overall Passing"], ascending=False)
top_performing_schools.head(5)
# Out:
#                              Total Students  Total School Budget  \
# school_name         type
# Pena High School    Charter             962             585858.0
# Holden High School  Charter             427             248087.0
# Wright High School  Charter            1800            1049400.0
# Thomas High School  Charter            1635            1043130.0
# Griffin High School Charter            1468             917500.0
#
#                              Per Student Budget  Average Math Score  \
# school_name         type
# Pena High School    Charter               609.0           83.839917
# Holden High School  Charter               581.0           83.803279
# Wright High School  Charter               583.0           83.682222
# Thomas High School  Charter               638.0           83.418349
# Griffin High School Charter               625.0           83.351499
#
#                              Average Reading Score  Per school passing math  \
# school_name         type
# ...

# %% [markdown]
# ## Bottom Performing Schools (By Passing Rate)

# %% [markdown]
# * Sort and display the five worst-performing schools

# %%
# The the five worst-performing schools. GJM
top_performing_schools = per_school_summary.sort_values(["Overall Passing"], ascending=True)
top_performing_schools.head(5)
# Out:
#                                 Total Students  Total School Budget  \
# school_name           type
# Rodriguez High School District            3999            2547363.0
# Ford High School      District            2739            1763916.0
# Huang High School     District            2917            1910635.0
# Bailey High School    District            4976            3124928.0
# Figueroa High School  District            2949            1884411.0
#
#                                 Per Student Budget  Average Math Score  \
# school_name           type
# Rodriguez High School District               637.0           76.842711
# Ford High School      District               644.0           77.102592
# Huang High School     District               655.0           76.629414
# Bailey High School    District               628.0           77.048432
# Figueroa High School  District               639.0           76.711767
#
#                                 Average Reading Score  \
# ...

# %% [markdown]
# ## Math Scores by Grade

# %% [markdown]
# * Create a table that lists the average Math Score for students of each grade level (9th, 10th, 11th, 12th) at each school.
#
#   * Create a pandas series for each grade. Hint: use a conditional statement.
#
#   * Group each series by school
#
#   * Combine the series into a dataframe
#
#   * Optional: give the displayed data cleaner formatting

# %%
ninth_grade_avg_math_score = school_data_complete[(school_data_complete["grade"]== "9th")].groupby(["school_name"]).mean()["math_score"]
tenth_grade_avg_math_score = school_data_complete[(school_data_complete["grade"]== "10th")].groupby(["school_name"]).mean()["math_score"]
eleventh_grade_avg_math_score = school_data_complete[(school_data_complete["grade"]== "11th")].groupby(["school_name"]).mean()["math_score"]
twelveth_grade_avg_math_score = school_data_complete[(school_data_complete["grade"]== "12th")].groupby(["school_name"]).mean()["math_score"]

avg_math_score_by_grade = pd.DataFrame({
    "ninth_grade_avg_math_score": ninth_grade_avg_math_score,
    "tenth_grade_avg_math_score": tenth_grade_avg_math_score,
    "eleventh_grade_avg_math_score": eleventh_grade_avg_math_score,
    "twelveth_grade_avg_math_score": twelveth_grade_avg_math_score,
})
avg_math_score_by_grade
# Out:
#                        ninth_grade_avg_math_score  tenth_grade_avg_math_score  \
# school_name
# Bailey High School                      77.083676                   76.996772
# Cabrera High School                     83.094697                   83.154506
# Figueroa High School                    76.403037                   76.539974
# Ford High School                        77.361345                   77.672316
# Griffin High School                     82.044010                   84.229064
# Hernandez High School                   77.438495                   77.337408
# Holden High School                      83.787402                   83.429825
# Huang High School                       77.027251                   75.908735
# Johnson High School                     77.187857                   76.691117
# Pena High School                        83.625455                   83.372000
# Rodriguez High School                   76.859966                   76.612500
# ...

# %% [markdown]
# ## Reading Score by Grade

# %% [markdown]
# * Perform the same operations as above for reading scores

# %%
ninth_grade_avg_reading_score = school_data_complete[(school_data_complete["grade"]== "9th")].groupby(["school_name"]).mean()["reading_score"]
tenth_grade_avg_reading_score = school_data_complete[(school_data_complete["grade"]== "10th")].groupby(["school_name"]).mean()["reading_score"]
eleventh_grade_avg_reading_score = school_data_complete[(school_data_complete["grade"]== "11th")].groupby(["school_name"]).mean()["reading_score"]
twelveth_grade_avg_reading_score = school_data_complete[(school_data_complete["grade"]== "12th")].groupby(["school_name"]).mean()["reading_score"]

avg_reading_score_by_grade = pd.DataFrame({
    "ninth_grade_avg_reading_score": ninth_grade_avg_math_score,
    "tenth_grade_avg_reading_score": tenth_grade_avg_reading_score,
    "eleventh_grade_avg_reading_score": eleventh_grade_avg_reading_score,
    "twelveth_grade_avg_reading_score": twelveth_grade_avg_reading_score,
})
avg_reading_score_by_grade.head()
# Out:
#                       ninth_grade_avg_reading_score  \
# school_name
# Bailey High School                        77.083676
# Cabrera High School                       83.094697
# Figueroa High School                      76.403037
# Ford High School                          77.361345
# Griffin High School                       82.044010
#
#                       tenth_grade_avg_reading_score  \
# school_name
# Bailey High School                        80.907183
# Cabrera High School                       84.253219
# Figueroa High School                      81.408912
# Ford High School                          81.262712
# Griffin High School                       83.706897
#
#                       eleventh_grade_avg_reading_score  \
# school_name
# Bailey High School                           80.945643
# Cabrera High School                          83.788382
# Figueroa High School                         80.640339
# Ford High School                             80.403642
# ...

# %% [markdown]
# ## Scores by School Spending

# %% [markdown]
# * Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)

# %%
# Sample bins. Feel free to create your own bins.
spending_bins = [0, 585, 615, 645, 675]
group_names = ["<$585", "$585-615", "$615-645", "$645-675"]

# %% [markdown]
# ## Scores by School Size

# %% [markdown]
# * Perform the same operations as above, based on school size.

# %%
# Sample bins. Feel free to create your own bins.
size_bins = [0, 1000, 2000, 5000]
group_names = ["Small (<1000)", "Medium (1000-2000)", "Large (2000-5000)"]

# %% [markdown]
# ## Scores by School Type

# %% [markdown]
# * Perform the same operations as above, based on school type.
